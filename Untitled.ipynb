# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    classification_report, roc_auc_score)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, RandomizedSearchCV

import os
import joblib
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv("C:\\Users\\Admin\\Desktop\\churns projects chatgpt\\data\\raw\\WA_Fn-UseC_-Telco-Customer-Churn (1).csv")

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.shape

# %%
df['Churn'].value_counts()

# %%
df['Churn'].value_counts(normalize=True)*100

# %%
sns.countplot(x ='Churn', data=df)
plt.title("Customer Churn Distribution")
plt.show()

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title("Churn by Contract Type")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title("Monthly Charges vs Churn")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Churn', y='tenure', data=df)
plt.title("Tenure vs Churn")
plt.show()

# %%
df.drop(columns=['customerID'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 df.drop(columns=['customerID'], inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'Contract_One year', 'Contract_Two year',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
FEATURES_22 = [
    'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
       'MonthlyCharges', 'TotalCharges', 'Churn'
]

# %%
binary_map = {
    "Yes": 1,
    "No": 0,
    "Male": 1,
    "Female": 0
}

binary_cols = [
    'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
    'StreamingTV', 'StreamingMovies', 'PaperlessBilling'
]

for col in binary_cols:
    df[col] = df[col].map(binary_map)

# %%
df = pd.get_dummies(
    df,
    columns=['InternetService', 'Contract', 'PaymentMethod'],
    drop_first=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 df = pd.get_dummies(
#       2     df,
#       3     columns=['InternetService', 'Contract', 'PaymentMethod'],
#       4     drop_first=True
#       5 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:170, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     168     raise TypeError("Input must be a list-like for parameter `columns`")
#     169 else:
# --> 170     data_to_encode = data[columns]
#     172 # validate prefixes and separator to avoid silently dropping cols
#     173 def check_len(item, name: str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# ...

# %%
df.shape
# Out:
# (7032, 24)

# %%
FEATURES_22 = df.drop("Churn", axis=1).columns.tolist()
len(FEATURES_22), FEATURES_22
# Out:
# (23,
#  ['gender',
#   'SeniorCitizen',
#   'Partner',
#   'Dependents',
#   'tenure',
#   'PhoneService',
#   'MultipleLines',
#   'OnlineSecurity',
#   'OnlineBackup',
#   'DeviceProtection',
#   'TechSupport',
#   'StreamingTV',
#   'StreamingMovies',
#   'PaperlessBilling',
#   'MonthlyCharges',
#   'TotalCharges',
#   'InternetService_Fiber optic',
#   'InternetService_No',
#   'Contract_One year',
#   'Contract_Two year',
#   'PaymentMethod_Credit card (automatic)',
#   'PaymentMethod_Electronic check',
#   'PaymentMethod_Mailed check'])

# %%
X = df[FEATURES_22]
y = df["Churn"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    stratify=y,
    random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 4
#       1 X = df[FEATURES_22]
#       2 y = df["Churn"]
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(
#       5     X, y,
#       6     test_size=0.25,
#       7     stratify=y,
#       8     random_state=42
#       9 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
X.isna().sum().sort_values(ascending=False)
# Out:
# gender                                   7032
# OnlineSecurity                           7032
# PaperlessBilling                         7032
# StreamingMovies                          7032
# TechSupport                              7032
# DeviceProtection                         7032
# OnlineBackup                             7032
# StreamingTV                              7032
# MultipleLines                            7032
# PhoneService                             7032
# Dependents                               7032
# Partner                                  7032
# tenure                                      0
# SeniorCitizen                               0
# MonthlyCharges                              0
# TotalCharges                                0
# InternetService_Fiber optic                 0
# InternetService_No                          0
# Contract_One year                           0
# Contract_Two year                           0
# ...

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# %%
logistic_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(
        max_iter=1000,
        class_weight="balanced"
    ))
])

# Train
logistic_pipeline.fit(X_train, y_train)

# Predict
lr_pred = logistic_pipeline.predict(X_test)
lr_prob = logistic_pipeline.predict_proba(X_test)[:, 1]

# Metrics
lr_auc = roc_auc_score(y_test, lr_prob)

print("🔹 Logistic Regression ROC-AUC:", lr_auc)
print(classification_report(y_test, lr_pred))
# Out:
# 🔹 Logistic Regression ROC-AUC: 0.8398938790539678
#               precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80      1291
#            1       0.50      0.80      0.61       467
#
#     accuracy                           0.73      1758
#    macro avg       0.70      0.75      0.70      1758
# weighted avg       0.80      0.73      0.75      1758

# %%
logistic_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler()),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_prob = logistic_pipeline.predict_proba(X_test)[:, 1]

print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# ROC-AUC: 0.8398938790539678

# %%
X = X.fillna(X.median())

# %%
rf_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("model", RandomForestClassifier(
        n_estimators=300,
        max_depth=10,
        class_weight="balanced",
        random_state=42
    ))
])

# Train
rf_pipeline.fit(X_train, y_train)

# Predict
rf_pred = rf_pipeline.predict(X_test)
rf_prob = rf_pipeline.predict_proba(X_test)[:, 1]

# Metrics
rf_auc = roc_auc_score(y_test, rf_prob)

print("🔹 Random Forest ROC-AUC:", rf_auc)
print(classification_report(y_test, rf_pred))
# Out:
# 🔹 Random Forest ROC-AUC: 0.8379449557718813
#               precision    recall  f1-score   support
#
#            0       0.89      0.79      0.84      1291
#            1       0.56      0.72      0.63       467
#
#     accuracy                           0.77      1758
#    macro avg       0.72      0.76      0.73      1758
# weighted avg       0.80      0.77      0.78      1758

# %%
comparison = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest"],
    "ROC_AUC": [lr_auc, rf_auc]
})

comparison.sort_values(by="ROC_AUC", ascending=False)
# Out:
#                  Model   ROC_AUC
# 0  Logistic Regression  0.839894
# 1        Random Forest  0.837945

# %%
param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf = RandomForestClassifier(
    random_state=42,
    class_weight='balanced'
)

rf_search = RandomizedSearchCV(
    rf,
    param_distributions=param_dist,
    n_iter=15,
    scoring='roc_auc',
    cv=5,
    n_jobs=-1,
    random_state=42
)

rf_search.fit(X_train, y_train)

best_rf = rf_search.best_estimator_
rf_tuned_prob = best_rf.predict_proba(X_test)[:, 1]

print("Best Params:", rf_search.best_params_)
print("Tuned RF ROC-AUC:", roc_auc_score(y_test, rf_tuned_prob))
# Out:
# Best Params: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_depth': 10}
# Tuned RF ROC-AUC: 0.8401260911897058

# %%
feat_imp = pd.DataFrame({
    "Feature": X.columns,
    "Importance": best_rf.feature_importances_
}).sort_values(by="Importance", ascending=False)

feat_imp.head(10)
# Out:
#                            Feature  Importance
# 4                           tenure    0.162111
# 15                    TotalCharges    0.122528
# 10                     TechSupport    0.101462
# 14                  MonthlyCharges    0.094586
# 19               Contract_Two year    0.090857
# 7                   OnlineSecurity    0.078923
# 16     InternetService_Fiber optic    0.066114
# 21  PaymentMethod_Electronic check    0.043735
# 18               Contract_One year    0.034702
# 8                     OnlineBackup    0.029367

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Importance', y='Feature', data=feat_imp.head(10))
plt.title("Top Churn Drivers (Random Forest)")
plt.show()

# %%
def threshold_metrics(y_true, y_prob, threshold):
    y_pred = (y_prob >= threshold).astype(int)
    return {
        "Threshold": threshold,
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred)
    }

thresholds = np.arange(0.3, 0.8, 0.05)
threshold_results = [threshold_metrics(y_test, rf_tuned_prob, t) for t in thresholds]

pd.DataFrame(threshold_results)
# Out:
#    Threshold  Precision    Recall
# 0       0.30   0.440426  0.886510
# 1       0.35   0.463835  0.865096
# 2       0.40   0.492537  0.847966
# 3       0.45   0.517956  0.802998
# 4       0.50   0.548438  0.751606
# 5       0.55   0.575972  0.698073
# 6       0.60   0.607438  0.629550
# 7       0.65   0.635468  0.552463
# 8       0.70   0.655589  0.464668
# 9       0.75   0.691450  0.398287

# %%
y_pred = log_model.predict(X_test_scaled)
y_pred_prob = log_model.predict_proba(X_test_scaled)[:, 1]
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 y_pred = log_model.predict(X_test_scaled)
#       2 y_pred_prob = log_model.predict_proba(X_test_scaled)[:, 1]
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:349, in LinearClassifierMixin.decision_function(self, X)
#     330 def decision_function(self, X):
#     331     """
#     332     Predict confidence scores for samples.
# ...

# %%
joblib.dump(best_rf, "churn_model.pkl")
joblib.dump(scaler, "scaler.pkl")

# %%
df_raw = pd.read_csv("C:\\Users\\Admin\\Desktop\\churns projects chatgpt\\data\\raw\\WA_Fn-UseC_-Telco-Customer-Churn (1).csv")

# ALWAYS remove identifiers first
df_raw.drop(columns=["customerID"], inplace=True)

# Encode target
df_raw["Churn"] = df_raw["Churn"].map({"Yes": 1, "No": 0})

# One-hot encode remaining categorical features
df_clean = pd.get_dummies(df_raw, drop_first=True)

df_clean.shape

# %%
# save cleaned dataset
df_clean.to_csv("C:\\Users\\Admin\\Desktop\\churns projects chatgpt\\data\\cleaned\\cleaned_telco_churn2.csv", index=False)
